# %%
from StanfordCitationNetwork.CitationPaperNode import CitationPaperNode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from StanfordCitationNetwork.CitationPaperNode import CitationPaperNode
#
# ModuleNotFoundError: No module named 'StanfordCitationNetwork'

# %%
import Framework

# %%
import pickle

# %%
citation_node = {}
with open("CitationCleaned.dat", "rb") as f:  # Open in binary mode
    citation_node = pickle.load(f)

# %%
citation_node.__dict__
# Out:
# {'NodeMapByType': {'CitationPaperNode': {'0001001': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f79f70>,
#    '9304045': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390e01820>,
#    '9308122': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d580>,
#    '9309097': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d610>,
#    '9311042': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d6a0>,
#    '9401139': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d730>,
#    '9404151': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d7c0>,
#    '9407087': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d850>,
#    '9408099': <StanfordCitationNetwork.CitationPaperNode.CitationPaperNode at 0x7fc390f7d8e0>,
# ...

# %%
type(citation_node.NodeMapByType)
# Out:
# dict

# %%
citation_node.NodeMapByType['CitationPaperNode']['0001001'].Dt
# Out:
# datetime.datetime(2000, 1, 1, 0, 0)
